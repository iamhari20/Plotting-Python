# %%
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sea

# %% [markdown]
# #### This dataset is all about top 1000 celebrity in instagram. It contains about the country,rank,account,category,followers and so on.

# %%
df=pd.read_csv("E:/python assignment/instagram_global_top_1000.csv")

# %%
df
# Out:
#     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               1000 non-null   object
#  1   Rank                  1000 non-null   int64
#  2   Account               1000 non-null   object
#  3   Title                 983 non-null    object
#  4   Link                  1000 non-null   object
#  5   Category              909 non-null    object
#  6   Followers             1000 non-null   int64
#  7   Audience Country      993 non-null    object
#  8   Authentic_engagement  1000 non-null   int64
#  9   Engagement avg        1000 non-null   int64
#  10  Scraped               1000 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 86.1+ KB

# %% [markdown]
# #### In this dataset ,it shows us the basic statistical data of dataset like mean,count

# %%
mat.boxplot(df['Followers'])
mat.show()

# %% [markdown]
# ### the boxplot is created for followers variable and the boxplot shows more values are in 0 to 0.2

# %%
mat.hist(df['Followers'])
mat.yscale('log')
mat.show()

# %% [markdown]
# ### The y-axis has taken log for better understanding of the variable

# %%
mat.hist(df['Followers'],color='y')
mat.show()

# %% [markdown]
# ###  Histogram chart is created by using hist function and the histogram shows that the values from 0 to 0.5 has has large number of volumes

# %%
mat.scatter(df['Authentic_engagement'],df['Engagement avg'])
mat.show()

# %% [markdown]
# ### using two variables named 'Authentic_engagement'and 'Engagement avg' the scatterplot has been created and the more number of lies bewteen o.o to 0.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               1000 non-null   object
#  1   Rank                  1000 non-null   int64
#  2   Account               1000 non-null   object
#  3   Title                 983 non-null    object
#  4   Link                  1000 non-null   object
#  5   Category              909 non-null    object
#  6   Followers             1000 non-null   int64
#  7   Audience Country      993 non-null    object
#  8   Authentic_engagement  1000 non-null   int64
#  9   Engagement avg        1000 non-null   int64
#  10  Scraped               1000 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 86.1+ KB

# %% [markdown]
# ### Info operation used to find the character type of each variable and the memory used by the dataset

# %%
mat.scatter(df['Followers'],df['Authentic_engagement'])
mat.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### for the variables 'Followers' and 'Authentic_engagement' , the scatterplot is created and more number of values lies between 0 to 0.8

# %%
sea.distplot(df['Followers'])
mat.show()
# Out:
# C:\Users\srhar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### distplot chart is created for the 'Followers' variable which shows that high number of values are lies form 0 to 0.2

# %%
sea.distplot(df['Followers'][:200], rug=True)
mat.show()
# Out:
# C:\Users\srhar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\srhar\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### using 'Followers' variable with observations less than 200 are created  with a distplot and using the rug it has highlighted the data which has values in the bottom of the values , the values from 0 to 0.8 has more number of values

# %%
sea.distplot(df['Followers'],hist=False)
mat.show()
# Out:
# C:\Users\srhar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### by giving false to the distplot, it removes the barplot from the chart

# %%
#subplot 1
mat.subplot(2,2,1)
mat.title('Followers')
sea.distplot(df['Followers'])

#subplots 2
mat.subplot(2,2,2)
mat.title('Authentic_engagement')
sea.distplot(df['Authentic_engagement'])

#subplots 3
mat.subplot(2,2,3)
#mat.title('Engagement avg')
sea.distplot(df['Engagement avg'])

#subplots 4
mat.subplot(2,2,4)
#mat.title('Rank')
sea.distplot(df['Rank'])
mat.tight_layout()
mat.show()
# Out:
# C:\Users\srhar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\srhar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### for the variables 'Followers' ,'Authentic_engagement' and 'rank' , subplots has been created.

# %%
sea.boxplot(df['Followers'])
mat.title('Followers')
mat.show()
# Out:
# C:\Users\srhar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### boxplot is created for 'Followers' and boxplot shows that the high values lies between 0 to 0.3

# %%
sea.boxplot(y=df['Followers'])
mat.title('Followers')
mat.show()

# %% [markdown]
# ### boxplot is changed to horizontal view for better understanding  of the plot

# %%
sea.jointplot('Followers','Authentic_engagement',df)
mat.show()
# Out:
# C:\Users\srhar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### for the 'Followers' and 'Authentic_engagement' variables , jointplot is created . for values 0 to 1 it les between 0.0 to 0.3 as it is the highest values in the plot. 'Followers' variables is shown inside the plot and 'Authentic_engagement' variables is shown outside the plot

# %%
df1=df[(df.Followers<6000000)&(df.Authentic_engagement>200000)]
sea.jointplot(x='Followers',y='Authentic_engagement',data=df1)
mat.show()

# %% [markdown]
# ### for the variable 'Followers'  which having values lesser than 6000000 and the variable 'Authentic_engagement'  which having values lesser than 200000 has been taken for creating the jointplot and the plot shows that from 0.2 to 1.2 more values are located and there are outliers which has the value around 1.4 to 1.6

# %%
df1=df[(df.Followers<100000)&(df.Authentic_engagement<200000)]
sea.jointplot(x='Authentic_engagement',y='Followers',data=df,kind="hex",color="k")
mat.show()
